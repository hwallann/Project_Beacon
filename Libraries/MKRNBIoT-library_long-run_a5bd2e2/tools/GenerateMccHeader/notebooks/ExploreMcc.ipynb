# %%
from requests import get
from bs4 import BeautifulSoup, NavigableString

# %%
mmcmnc_url_source = "https://en.wikipedia.org/wiki/Mobile_country_code"

# %%
def parse_operators(operators_tag):
    rows = operators_tag.find_all('tr')[1:]
    operators = []
    for row in rows:
        def contents(t):
            print(t)
            ''.join([p.string for p in t.contents if len(t.contents) > 0])
        MCC, MNC, Brand, Operator, Status, Bands, _ = [''.join(td.strings) for td in row.find_all('td')]
        Brand = Brand if Brand is not None else 'Unknown'
        Operator = Operator if Operator is not None else 'Unknown'
        operators.append((MCC, MNC, Brand, Operator, Status, Bands))
    return operators

# %%
def parse_table(table_tag):
    operators_table = table_tag.find_next('table', {'class': 'wikitable'})
    return parse_operators(operators_table)

# %%
def print_operators(nation, opers):
    for MCC, MNC, Brand, Operator, Status, Bands in opers:
        print(f'{nation}, {MCC}, {MNC}, {Brand}, {Operator}, {Status}, {Bands}')

# %%
def parse_nation(nation_tag):
    Nation = nation_tag.a.string
    opers = parse_table(nation_tag)
    k = ["Nation", "MCC", "MNC", "Brand", "Operator", "Status", "Bands"]
    return [ dict([(k, v) for k, v in zip(k, (Nation, *oper))]) for oper in opers ]

# %%
def parse_intl(intl_tag):
    Nation = intl_tag.span['id']
    intls = parse_table(intl_tag)
    k = ["Nation", "MCC", "MNC", "Brand", "Operator", "Status", "Bands"]
    return [ dict([(k, v) for k, v in zip(k, (Nation, *oper))]) for oper in intls ]

# %%
mmcmnc_page = get(mmcmnc_url_source)

# %%
html = BeautifulSoup(mmcmnc_page.content, 'html.parser')

# %%
nations = html.find_all('h4')

# %%
tables = html.find_all('table', {'class': 'wikitable'})[1:]

# %%
tables
# Out:
# [<table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>289</td>
#  <td>67</td>
#  <td>Aquafon</td>
#  <td>Aquafon JSC</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 800</td>
#  <td>MCC is not listed by ITU;<sup class="reference" id="cite_ref-itu_ob_1117_3-0"><a href="#cite_note-itu_ob_1117-3">[3]</a></sup> LTE band 20<sup class="reference" id="cite_ref-gsa_lte_4-0"><a href="#cite_note-gsa_lte-4">[4]</a></sup>
#  </td></tr>
#  <tr>
#  <td>289</td>
#  <td>88</td>
#  <td>A-Mobile</td>
#  <td>A-Mobile LLSC</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 800 / LTE 1800</td>
#  <td>MCC is not listed by ITU<sup class="reference" id="cite_ref-itu_ob_1117_3-1"><a href="#cite_note-itu_ob_1117-3">[3]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>412</td>
#  <td>01</td>
#  <td><a href="/wiki/Afghan_Wireless" title="Afghan Wireless">AWCC</a></td>
#  <td><a href="/wiki/Afghan_Wireless" title="Afghan Wireless">Afghan Wireless Communication Company</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>412</td>
#  <td>20</td>
#  <td><a href="/wiki/Roshan_(telco)" title="Roshan (telco)">Roshan</a></td>
#  <td>Telecom Development Company Afghanistan Ltd.</td>
#  <td>Operational</td>
#  <td>GSM 900 / UMTS</td>
#  <td><sup class="reference" id="cite_ref-gsa_hspa_5-0"><a href="#cite_note-gsa_hspa-5">[5]</a></sup>
#  </td></tr>
#  <tr>
#  <td>412</td>
#  <td>40</td>
#  <td><a href="/wiki/MTN_Group" title="MTN Group">MTN</a></td>
#  <td><a href="/wiki/MTN_Group" title="MTN Group">MTN Group</a> Afghanistan</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100</td>
#  <td><sup class="reference" id="cite_ref-gsa_hspa_5-1"><a href="#cite_note-gsa_hspa-5">[5]</a></sup>
#  </td></tr>
#  <tr>
#  <td>412</td>
#  <td>50</td>
#  <td><a class="mw-redirect" href="/wiki/Emirates_Telecommunications_Corporation" title="Emirates Telecommunications Corporation">Etisalat</a></td>
#  <td>Etisalat Afghanistan</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1025_6-0"><a href="#cite_note-itu_ob_1025-6">[6]</a></sup><sup class="reference" id="cite_ref-gsa_hspa_5-2"><a href="#cite_note-gsa_hspa-5">[5]</a></sup>
#  </td></tr>
#  <tr>
#  <td>412</td>
#  <td>55</td>
#  <td>WASEL</td>
#  <td>WASEL Afghanistan</td>
#  <td>Operational</td>
#  <td>CDMA 800</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>412</td>
#  <td>80</td>
#  <td>Salaam</td>
#  <td><a href="/wiki/Afghan_Telecom" title="Afghan Telecom">Afghan Telecom</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1025_6-1"><a href="#cite_note-itu_ob_1025-6">[6]</a></sup><sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup>
#  </td></tr>
#  <tr>
#  <td>412</td>
#  <td>88</td>
#  <td>Salaam</td>
#  <td><a href="/wiki/Afghan_Telecom" title="Afghan Telecom">Afghan Telecom</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-0"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>276</td>
#  <td>01</td>
#  <td>Telekom.al</td>
#  <td><a href="/wiki/Telekom_Albania" title="Telekom Albania">Telekom Albania</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800 / LTE 2600</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte_4-1"><a href="#cite_note-gsa_lte-4">[4]</a></sup>
#  </td></tr>
#  <tr>
#  <td>276</td>
#  <td>02</td>
#  <td>Vodafone</td>
#  <td><a href="/wiki/Vodafone_Albania" title="Vodafone Albania">Vodafone Albania</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800 / LTE 2600</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte_4-2"><a href="#cite_note-gsa_lte-4">[4]</a></sup>
#  </td></tr>
#  <tr>
#  <td>276</td>
#  <td>03</td>
#  <td><a class="mw-redirect" href="/wiki/Eagle_Mobile" title="Eagle Mobile">Eagle Mobile</a></td>
#  <td><a href="/wiki/Albtelecom" title="Albtelecom">Albtelecom</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte_4-3"><a href="#cite_note-gsa_lte-4">[4]</a></sup>
#  </td></tr>
#  <tr>
#  <td>276</td>
#  <td>04</td>
#  <td><a href="/wiki/Plus_Communication" title="Plus Communication">Plus Communication</a></td>
#  <td>Plus Communication</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100</td>
#  <td><sup class="reference" id="cite_ref-mwlive_9-0"><a href="#cite_note-mwlive-9">[9]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>603</td>
#  <td>01</td>
#  <td>Mobilis</td>
#  <td><a href="/wiki/Alg%C3%A9rie_T%C3%A9l%C3%A9com" title="Algérie Télécom">Algérie Télécom</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-gsa_hspa_5-3"><a href="#cite_note-gsa_hspa-5">[5]</a></sup>
#  </td></tr>
#  <tr>
#  <td>603</td>
#  <td>02</td>
#  <td><a href="/wiki/Djezzy" title="Djezzy">Djezzy</a></td>
#  <td><a class="mw-redirect" href="/wiki/Optimum_Telecom" title="Optimum Telecom">Optimum Telecom</a> Algérie Spa</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td>Former <a class="mw-redirect" href="/wiki/Orascom_Telecom" title="Orascom Telecom">Orascom Telecom</a>
#  </td></tr>
#  <tr>
#  <td>603</td>
#  <td>03</td>
#  <td><a href="/wiki/Ooredoo" title="Ooredoo">Ooredoo</a></td>
#  <td>Wataniya Telecom Algérie</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-gsa_hspa_5-4"><a href="#cite_note-gsa_hspa-5">[5]</a></sup> Former Nedjma
#  </td></tr>
#  <tr>
#  <td>603</td>
#  <td>07</td>
#  <td>AT</td>
#  <td><a href="/wiki/Alg%C3%A9rie_T%C3%A9l%C3%A9com" title="Algérie Télécom">Algérie Télécom</a></td>
#  <td>Operational</td>
#  <td>CDMA 1900</td>
#  <td>Wireless Local Loop<sup class="reference" id="cite_ref-itu_ob_1118_10-0"><a href="#cite_note-itu_ob_1118-10">[10]</a></sup>
#  </td></tr>
#  <tr>
#  <td>603</td>
#  <td>09</td>
#  <td>AT</td>
#  <td><a href="/wiki/Alg%C3%A9rie_T%C3%A9l%C3%A9com" title="Algérie Télécom">Algérie Télécom</a></td>
#  <td>Operational</td>
#  <td>LTE</td>
#  <td>Fixed Wireless Broadband<sup class="reference" id="cite_ref-itu_ob_1118_10-1"><a href="#cite_note-itu_ob_1118-10">[10]</a></sup>
#  </td></tr>
#  <tr>
#  <td>603</td>
#  <td>21</td>
#  <td>ANESRIF</td>
#  <td><a href="/wiki/Anesrif" title="Anesrif">Anesrif</a></td>
#  <td>Ongoing</td>
#  <td>GSM-R</td>
#  <td>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>544</td>
#  <td>11</td>
#  <td>Bluesky</td>
#  <td>Bluesky</td>
#  <td>Operational</td>
#  <td>GSM 850 / GSM 1900 / UMTS 850 / LTE 700 / LTE 1700</td>
#  <td><sup class="reference" id="cite_ref-gsa_hspa_5-5"><a href="#cite_note-gsa_hspa-5">[5]</a></sup><sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>213</td>
#  <td>03</td>
#  <td>Mobiland</td>
#  <td>Servei De Tele. DAndorra</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 800</td>
#  <td>LTE band 20<sup class="reference" id="cite_ref-gsa_lte_4-4"><a href="#cite_note-gsa_lte-4">[4]</a></sup><sup class="reference" id="cite_ref-gsa_hspa_5-6"><a href="#cite_note-gsa_hspa-5">[5]</a></sup><sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>631</td>
#  <td>02</td>
#  <td><a href="/wiki/Unitel_(Angola)" title="Unitel (Angola)">UNITEL</a></td>
#  <td>UNITEL S.a.r.l.</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte1800_101213_13-0"><a href="#cite_note-gsa_lte1800_101213-13">[13]</a></sup><sup class="reference" id="cite_ref-gsma_angola_14-0"><a href="#cite_note-gsma_angola-14">[14]</a></sup><sup class="reference" id="cite_ref-4g_statusafrica_070314_15-0"><a href="#cite_note-4g_statusafrica_070314-15">[15]</a></sup>
#  </td></tr>
#  <tr>
#  <td>631</td>
#  <td>04</td>
#  <td><a href="/wiki/Movicel" title="Movicel">MOVICEL</a></td>
#  <td>MOVICEL Telecommunications S.A.</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 900 / LTE 1800</td>
#  <td>CDMA shut down March 2016<sup class="reference" id="cite_ref-gsa_hspa_5-7"><a href="#cite_note-gsa_hspa-5">[5]</a></sup><sup class="reference" id="cite_ref-gsa_lte1800_101213_13-1"><a href="#cite_note-gsa_lte1800_101213-13">[13]</a></sup><sup class="reference" id="cite_ref-gsma_angola_14-1"><a href="#cite_note-gsma_angola-14">[14]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>365</td>
#  <td>010</td>
#  <td></td>
#  <td>Weblinks Limited</td>
#  <td>Operational</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>365</td>
#  <td>840</td>
#  <td><a href="/wiki/Flow_(brand)" title="Flow (brand)">FLOW</a></td>
#  <td>Cable &amp; Wireless</td>
#  <td>Operational</td>
#  <td>GSM 850 / UMTS / LTE 700</td>
#  <td><sup class="reference" id="cite_ref-gsa_hspa_5-8"><a href="#cite_note-gsa_hspa-5">[5]</a></sup><sup class="reference" id="cite_ref-gsa_edge_030513_16-0"><a href="#cite_note-gsa_edge_030513-16">[16]</a></sup><sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>344</td>
#  <td>030</td>
#  <td>APUA</td>
#  <td>Antigua Public Utilities Authority</td>
#  <td>Operational</td>
#  <td>GSM 1900</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>344</td>
#  <td>050</td>
#  <td><a href="/wiki/Digicel" title="Digicel">Digicel</a></td>
#  <td>Antigua Wireless Ventures Limited</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1900 / UMTS 850 / LTE 700</td>
#  <td>LTE band 17 <sup class="reference" id="cite_ref-gsa_hspa_5-9"><a href="#cite_note-gsa_hspa-5">[5]</a></sup><sup class="reference" id="cite_ref-18"><a href="#cite_note-18">[18]</a></sup>
#  </td></tr>
#  <tr>
#  <td>344</td>
#  <td>920</td>
#  <td><a href="/wiki/Flow_(brand)" title="Flow (brand)">FLOW</a></td>
#  <td>Cable &amp; Wireless Caribbean Cellular (Antigua) Limited</td>
#  <td>Operational</td>
#  <td>GSM 850 / GSM 1800 / GSM 1900 / UMTS / LTE 1700</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte_4-5"><a href="#cite_note-gsa_lte-4">[4]</a></sup><sup class="reference" id="cite_ref-gsa_hspa_5-10"><a href="#cite_note-gsa_hspa-5">[5]</a></sup>
#  </td></tr>
#  <tr>
#  <td>344</td>
#  <td>930</td>
#  <td></td>
#  <td>AT&amp;T Wireless</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-1"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>722</td>
#  <td>010</td>
#  <td><a href="/wiki/Movistar" title="Movistar">Movistar</a></td>
#  <td>Telefónica Móviles Argentina S.A.</td>
#  <td>Operational</td>
#  <td>GSM 850 / GSM 1900 / UMTS / LTE 1700</td>
#  <td><sup class="reference" id="cite_ref-gsa_hspa_5-11"><a href="#cite_note-gsa_hspa-5">[5]</a></sup><sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[19]</a></sup>
#  </td></tr>
#  <tr>
#  <td>722</td>
#  <td>020</td>
#  <td>Nextel</td>
#  <td><a href="/wiki/NII_Holdings" title="NII Holdings">NII Holdings</a></td>
#  <td>Operational</td>
#  <td>iDEN 800</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>722</td>
#  <td>034</td>
#  <td>Personal</td>
#  <td><a class="mw-redirect" href="/wiki/Telecom_Personal#Personal" title="Telecom Personal">Telecom Personal S.A.</a></td>
#  <td>Operational</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>722</td>
#  <td>040</td>
#  <td>Globalstar</td>
#  <td>TE.SA.M Argentina S.A.</td>
#  <td>Operational</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>722</td>
#  <td>070</td>
#  <td><a href="/wiki/Movistar" title="Movistar">Movistar</a></td>
#  <td>Telefónica Móviles Argentina S.A.</td>
#  <td>Operational</td>
#  <td>GSM 1900</td>
#  <td>Also uses or had used MNC 07
#  </td></tr>
#  <tr>
#  <td>722</td>
#  <td>310</td>
#  <td><a class="mw-redirect" href="/wiki/Claro_Americas" title="Claro Americas">Claro</a></td>
#  <td>AMX Argentina S.A.</td>
#  <td>Operational</td>
#  <td>GSM 1900</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>722</td>
#  <td>320</td>
#  <td><a class="mw-redirect" href="/wiki/Claro_Americas" title="Claro Americas">Claro</a></td>
#  <td>AMX Argentina S.A.</td>
#  <td>Operational</td>
#  <td>GSM 850 / GSM 1900 / UMTS / LTE 1700</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte_4-6"><a href="#cite_note-gsa_lte-4">[4]</a></sup><sup class="reference" id="cite_ref-gsa_hspa_5-12"><a href="#cite_note-gsa_hspa-5">[5]</a></sup>
#  </td></tr>
#  <tr>
#  <td>722</td>
#  <td>330</td>
#  <td><a class="mw-redirect" href="/wiki/Claro_Americas" title="Claro Americas">Claro</a></td>
#  <td>AMX Argentina S.A.</td>
#  <td>Operational</td>
#  <td>GSM 850 / GSM 1900 / UMTS / LTE 1700</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte_4-7"><a href="#cite_note-gsa_lte-4">[4]</a></sup><sup class="reference" id="cite_ref-gsa_hspa_5-13"><a href="#cite_note-gsa_hspa-5">[5]</a></sup>
#  </td></tr>
#  <tr>
#  <td>722</td>
#  <td>341</td>
#  <td>Personal</td>
#  <td><a class="mw-redirect" href="/wiki/Telecom_Personal#Personal" title="Telecom Personal">Telecom Personal S.A.</a></td>
#  <td>Operational</td>
#  <td>GSM 850 / GSM 1900 / UMTS / LTE 700 / LTE 1700 / LTE 2600</td>
#  <td>LTE bands 28 / 4 / 7<sup class="reference" id="cite_ref-itu_ob_1056_20-0"><a href="#cite_note-itu_ob_1056-20">[20]</a></sup><sup class="reference" id="cite_ref-gsa_lte_4-8"><a href="#cite_note-gsa_lte-4">[4]</a></sup><sup class="reference" id="cite_ref-gsa_hspa_5-14"><a href="#cite_note-gsa_hspa-5">[5]</a></sup>
#  </td></tr>
#  <tr>
#  <td>722</td>
#  <td>350</td>
#  <td>PORT-HABLE</td>
#  <td>Hutchison Telecommunications Argentina S.A.</td>
#  <td>Not operational</td>
#  <td>GSM 900</td>
#  <td>Acquired by Claro
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>283</td>
#  <td>01</td>
#  <td><a class="mw-redirect" href="/wiki/Beeline_(telecommunications)" title="Beeline (telecommunications)">Beeline</a></td>
#  <td><a class="mw-redirect" href="/wiki/ArmenTel" title="ArmenTel">ArmenTel</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 450 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte_4-9"><a href="#cite_note-gsa_lte-4">[4]</a></sup>
#  </td></tr>
#  <tr>
#  <td>283</td>
#  <td>04</td>
#  <td>Karabakh Telecom</td>
#  <td>Karabakh Telecom</td>
#  <td>Operational</td>
#  <td>GSM 900 / UMTS 900</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>283</td>
#  <td>05</td>
#  <td>VivaCell-MTS</td>
#  <td>K Telecom CJSC</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 2600</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>283</td>
#  <td>10</td>
#  <td><a href="/wiki/Ucom" title="Ucom">Ucom</a></td>
#  <td>Ucom LLC</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 900 / UMTS 2100 / LTE 800 / LTE 1800</td>
#  <td>Former Orange
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>363</td>
#  <td>01</td>
#  <td><a href="/wiki/SetarNV" title="SetarNV">SETAR</a></td>
#  <td>Servicio di Telecomunicacion di Aruba</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / GSM 1900 / UMTS 2100 / LTE 1800 / TDMA 800</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte1800_101213_13-2"><a href="#cite_note-gsa_lte1800_101213-13">[13]</a></sup><sup class="reference" id="cite_ref-21"><a href="#cite_note-21">[21]</a></sup>
#  </td></tr>
#  <tr>
#  <td>363</td>
#  <td>02</td>
#  <td><a href="/wiki/Digicel" title="Digicel">Digicel</a></td>
#  <td>Digicel Aruba</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100</td>
#  <td>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td></td>
#  <td></td>
#  <td></td>
#  <td></td>
#  <td></td>
#  <td></td>
#  <td>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>505</td>
#  <td>01</td>
#  <td><a href="/wiki/Telstra" title="Telstra">Telstra</a></td>
#  <td><a href="/wiki/Telstra" title="Telstra">Telstra Corporation Limited</a></td>
#  <td>Operational</td>
#  <td>UMTS 850 / UMTS 2100 / LTE 700 / LTE 900 / LTE 1800 / LTE 2100</td>
#  <td>LTE bands 28 / 8 / 3 / 1;<sup class="reference" id="cite_ref-gsa_lte_4-10"><a href="#cite_note-gsa_lte-4">[4]</a></sup> GSM was closed on 1 December 2016 <sup class="reference" id="cite_ref-22"><a href="#cite_note-22">[22]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>02</td>
#  <td><a href="/wiki/Optus" title="Optus">Optus</a></td>
#  <td><a href="/wiki/Optus" title="Optus">Singtel Optus Proprietary Limited</a></td>
#  <td>Operational</td>
#  <td>UMTS 900 / UMTS 2100 / LTE 700 / LTE 1800 / LTE 2100 / TD-LTE 2300</td>
#  <td>LTE bands 28 / 3 / 1 / 40;<sup class="reference" id="cite_ref-gsa_lte_4-11"><a href="#cite_note-gsa_lte-4">[4]</a></sup> GSM was closed on 1 August 2017<sup class="reference" id="cite_ref-23"><a href="#cite_note-23">[23]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>03</td>
#  <td><a href="/wiki/Vodafone" title="Vodafone">Vodafone</a></td>
#  <td><a class="mw-redirect" href="/wiki/Vodafone_Hutchison_Australia" title="Vodafone Hutchison Australia">Vodafone Hutchison Australia Proprietary Limited</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 850 / UMTS 900 / UMTS 2100 / LTE 850 / LTE 1800 / LTE 2100</td>
#  <td>LTE bands 5 / 3 / 1;<sup class="reference" id="cite_ref-gsa_lte_4-12"><a href="#cite_note-gsa_lte-4">[4]</a></sup> GSM to shut down 30 September 2017<sup class="reference" id="cite_ref-shutdown2G_24-0"><a href="#cite_note-shutdown2G-24">[24]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>04</td>
#  <td></td>
#  <td><a href="/wiki/Department_of_Defence_(Australia)" title="Department of Defence (Australia)">Department of Defence</a></td>
#  <td>Operational</td>
#  <td>Unknown</td>
#  <td>Private network
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>05</td>
#  <td>Ozitel</td>
#  <td></td>
#  <td>Not operational</td>
#  <td></td>
#  <td>Brand was taken over by <a href="/wiki/Telstra" title="Telstra">Telstra</a>.
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>06</td>
#  <td><a class="mw-redirect" href="/wiki/Hutchison_3G" title="Hutchison 3G">3</a></td>
#  <td><a class="mw-redirect" href="/wiki/Vodafone_Hutchison_Australia" title="Vodafone Hutchison Australia">Vodafone Hutchison Australia Proprietary Limited</a></td>
#  <td>Not operational</td>
#  <td>UMTS 2100</td>
#  <td><a class="mw-redirect" href="/wiki/Vodafone_Hutchison_Australia" title="Vodafone Hutchison Australia">Vodafone Hutchison Australia</a> and <a href="/wiki/Telstra" title="Telstra">Telstra</a> ended their network sharing agreement on 31 August 2012. The 3TELSTRA network was shut down on this date.
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>07</td>
#  <td><a href="/wiki/Vodafone" title="Vodafone">Vodafone</a></td>
#  <td>Vodafone Network Pty. Ltd.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-2"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>08</td>
#  <td><a href="/wiki/One.Tel" title="One.Tel">One.Tel</a></td>
#  <td><a href="/wiki/One.Tel" title="One.Tel">One.Tel Limited</a></td>
#  <td>Not operational</td>
#  <td>GSM 900</td>
#  <td>Brand was dissolved.
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>09</td>
#  <td>Airnet</td>
#  <td></td>
#  <td>Not operational</td>
#  <td></td>
#  <td>No longer provide mobile services.
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>10</td>
#  <td>Norfolk Is.</td>
#  <td><a class="new" href="/w/index.php?title=Norfolk_Telecom&amp;action=edit&amp;redlink=1" title="Norfolk Telecom (page does not exist)">Norfolk Telecom</a></td>
#  <td>Operational</td>
#  <td>GSM 900</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>11</td>
#  <td><a href="/wiki/Telstra" title="Telstra">Telstra</a></td>
#  <td>Telstra Corporation Ltd.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-3"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>12</td>
#  <td><a class="mw-redirect" href="/wiki/Hutchison_3G" title="Hutchison 3G">3</a></td>
#  <td><a class="mw-redirect" href="/wiki/Vodafone_Hutchison_Australia" title="Vodafone Hutchison Australia">Vodafone Hutchison Australia Proprietary Limited</a></td>
#  <td>Not operational</td>
#  <td>UMTS 2100</td>
#  <td>See MNC 06
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>13</td>
#  <td><a href="/wiki/RailCorp" title="RailCorp">RailCorp</a></td>
#  <td>Railcorp, Transport for New South Wales</td>
#  <td>Operational</td>
#  <td>GSM-R 1800</td>
#  <td>For use by <a href="/wiki/Sydney_Trains" title="Sydney Trains">Sydney Trains</a> Digital Train Radio System<sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[25]</a></sup><sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[26]</a></sup><sup class="reference" id="cite_ref-27"><a href="#cite_note-27">[27]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>14</td>
#  <td><a href="/wiki/AAPT_Limited" title="AAPT Limited">AAPT</a></td>
#  <td><a href="/wiki/TPG_Telecom" title="TPG Telecom">TPG Telecom</a></td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>Wholesale from <a class="mw-redirect" href="/wiki/Vodafone_Hutchison_Australia" title="Vodafone Hutchison Australia">Vodafone Hutchison Australia</a>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>15</td>
#  <td>3GIS</td>
#  <td></td>
#  <td>Not operational</td>
#  <td></td>
#  <td>Taken over by <a class="mw-redirect" href="/wiki/Vodafone_Hutchison_Australia" title="Vodafone Hutchison Australia">Vodafone</a>.
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>16</td>
#  <td><a href="/wiki/VicTrack" title="VicTrack">VicTrack</a></td>
#  <td>Victorian Rail Track</td>
#  <td>Operational</td>
#  <td>GSM-R 1800</td>
#  <td>Digital Train Radio System
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>17</td>
#  <td></td>
#  <td><a href="/wiki/Optus" title="Optus">Optus</a></td>
#  <td>Unknown</td>
#  <td>TD-LTE 2300</td>
#  <td>Former Vivid Wireless Pty. Ltd.<sup class="reference" id="cite_ref-itu_ob_1019_8-4"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup><sup class="reference" id="cite_ref-gsa_lte_4-13"><a href="#cite_note-gsa_lte-4">[4]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>18</td>
#  <td>Pactel</td>
#  <td>Pactel International Pty Ltd</td>
#  <td>Unknown</td>
#  <td></td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>19</td>
#  <td><a href="/wiki/Lycamobile" title="Lycamobile">Lycamobile</a></td>
#  <td>Lycamobile Pty Ltd</td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>20</td>
#  <td></td>
#  <td>Ausgrid Corporation</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-5"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>21</td>
#  <td></td>
#  <td><a href="/wiki/Queensland_Rail" title="Queensland Rail">Queensland Rail</a> Limited</td>
#  <td>Unknown</td>
#  <td>GSM-R 1800</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-6"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>22</td>
#  <td></td>
#  <td><a href="/wiki/IiNet" title="IiNet">iiNet</a> Ltd</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-7"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>23</td>
#  <td></td>
#  <td>Challenge Networks Pty. Ltd.</td>
#  <td>Planning</td>
#  <td>LTE 2100</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-8"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>24</td>
#  <td></td>
#  <td>Advanced Communications Technologies Pty. Ltd.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>25</td>
#  <td></td>
#  <td><a href="/wiki/Pilbara_Iron" title="Pilbara Iron">Pilbara Iron</a> Company Services Pty Ltd</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-9"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>26</td>
#  <td></td>
#  <td>Dialogue Communications Pty. Ltd.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-10"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>27</td>
#  <td></td>
#  <td>Nexium Telecommunications</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-11"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>28</td>
#  <td></td>
#  <td>RCOM International Pty Ltd</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1027_28-0"><a href="#cite_note-itu_ob_1027-28">[28]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>30</td>
#  <td></td>
#  <td>Compatel Limited</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1055_29-0"><a href="#cite_note-itu_ob_1055-29">[29]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>31</td>
#  <td></td>
#  <td><a class="mw-redirect" href="/wiki/BHP_Billiton" title="BHP Billiton">BHP Billiton</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1056_20-1"><a href="#cite_note-itu_ob_1056-20">[20]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>32</td>
#  <td></td>
#  <td><a href="/wiki/Thales_Australia" title="Thales Australia">Thales Australia</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1065_30-0"><a href="#cite_note-itu_ob_1065-30">[30]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>33</td>
#  <td></td>
#  <td><a class="external text" href="https://clxnetworks.com/" rel="nofollow">CLX Networks Pty Ltd</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1088_31-0"><a href="#cite_note-itu_ob_1088-31">[31]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>34</td>
#  <td></td>
#  <td><a href="/wiki/Santos_Limited" title="Santos Limited">Santos Limited</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1096_32-0"><a href="#cite_note-itu_ob_1096-32">[32]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>35</td>
#  <td></td>
#  <td>MessageBird Pty Ltd</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1101_33-0"><a href="#cite_note-itu_ob_1101-33">[33]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>36</td>
#  <td><a href="/wiki/Optus" title="Optus">Optus</a></td>
#  <td>Optus Mobile Pty. Ltd.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1104_34-0"><a href="#cite_note-itu_ob_1104-34">[34]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>37</td>
#  <td></td>
#  <td><a class="external text" href="http://www.yancoal.com.au/" rel="nofollow">Yancoal Australia Ltd</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1106_35-0"><a href="#cite_note-itu_ob_1106-35">[35]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>38</td>
#  <td><a href="/wiki/Truphone" title="Truphone">Truphone</a></td>
#  <td>Truphone Pty Ltd</td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>Formerly <a href="/wiki/Crazy_John%27s" title="Crazy John's">Crazy John's</a><sup class="reference" id="cite_ref-itu_ob_1108_36-0"><a href="#cite_note-itu_ob_1108-36">[36]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>39</td>
#  <td><a href="/wiki/Telstra" title="Telstra">Telstra</a></td>
#  <td>Telstra Corporation Ltd.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1111_37-0"><a href="#cite_note-itu_ob_1111-37">[37]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>40</td>
#  <td></td>
#  <td><a href="/wiki/CITIC_Limited" title="CITIC Limited">CITIC Pacific Mining</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1112_38-0"><a href="#cite_note-itu_ob_1112-38">[38]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>41</td>
#  <td></td>
#  <td><a class="external text" href="http://www.aqura.com.au/" rel="nofollow">Aqura Technologies Pty</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td>Former OTOC<sup class="reference" id="cite_ref-itu_ob_1112_38-1"><a href="#cite_note-itu_ob_1112-38">[38]</a></sup><sup class="reference" id="cite_ref-itu_ob_1132_39-0"><a href="#cite_note-itu_ob_1132-39">[39]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>42</td>
#  <td><a href="/wiki/GEMCO" title="GEMCO">GEMCO</a></td>
#  <td>Groote Eylandt Mining Company Pty Ltd</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1121_40-0"><a href="#cite_note-itu_ob_1121-40">[40]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>43</td>
#  <td></td>
#  <td><a class="external text" href="https://www.arrowenergy.com.au/" rel="nofollow">Arrow Energy Pty Ltd</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1141_41-0"><a href="#cite_note-itu_ob_1141-41">[41]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>44</td>
#  <td></td>
#  <td><a href="/wiki/Roy_Hill" title="Roy Hill">Roy Hill</a> Iron Ore Pty Ltd</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1145_42-0"><a href="#cite_note-itu_ob_1145-42">[42]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>50</td>
#  <td></td>
#  <td>Pivotel Group Pty Limited</td>
#  <td>Operational</td>
#  <td>Satellite</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1136_43-0"><a href="#cite_note-itu_ob_1136-43">[43]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>61</td>
#  <td><a class="new" href="/w/index.php?title=CommTel_NS&amp;action=edit&amp;redlink=1" title="CommTel NS (page does not exist)">CommTel NS</a></td>
#  <td><a class="external text" href="http://www.commtelns.com/" rel="nofollow">Commtel Network Solutions Pty Ltd</a></td>
#  <td>Implement / Design</td>
#  <td>LTE 1800 / LTE 2100</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1114_44-0"><a href="#cite_note-itu_ob_1114-44">[44]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>62</td>
#  <td><a href="/wiki/National_Broadband_Network" title="National Broadband Network">NBN</a></td>
#  <td><a href="/wiki/National_Broadband_Network" title="National Broadband Network">National Broadband Network</a> Co.</td>
#  <td>Operational</td>
#  <td>TD-LTE 2300</td>
#  <td>LTE band 40<sup class="reference" id="cite_ref-gsa_lte_4-14"><a href="#cite_note-gsa_lte-4">[4]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>68</td>
#  <td><a href="/wiki/National_Broadband_Network" title="National Broadband Network">NBN</a></td>
#  <td><a href="/wiki/National_Broadband_Network" title="National Broadband Network">National Broadband Network</a> Co.</td>
#  <td>Operational</td>
#  <td>TD-LTE 2300</td>
#  <td>LTE band 40<sup class="reference" id="cite_ref-gsa_lte_4-15"><a href="#cite_note-gsa_lte-4">[4]</a></sup>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>71</td>
#  <td><a href="/wiki/Telstra" title="Telstra">Telstra</a></td>
#  <td><a href="/wiki/Telstra" title="Telstra">Telstra Corporation Limited</a></td>
#  <td>Operational</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>72</td>
#  <td><a href="/wiki/Telstra" title="Telstra">Telstra</a></td>
#  <td><a href="/wiki/Telstra" title="Telstra">Telstra Corporation Limited</a></td>
#  <td>Operational</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>88</td>
#  <td></td>
#  <td>Pivotel Group Pty Limited</td>
#  <td>Operational</td>
#  <td>Satellite</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1136_43-1"><a href="#cite_note-itu_ob_1136-43">[43]</a></sup> Former Localstar Holding Pty. Ltd.
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>90</td>
#  <td><a href="/wiki/Optus" title="Optus">Optus</a></td>
#  <td><a href="/wiki/Optus" title="Optus">Singtel Optus Proprietary Limited</a></td>
#  <td>Operational</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>505</td>
#  <td>99</td>
#  <td><a href="/wiki/One.Tel" title="One.Tel">One.Tel</a></td>
#  <td><a href="/wiki/One.Tel" title="One.Tel">One.Tel</a></td>
#  <td>Not operational</td>
#  <td>GSM 1800</td>
#  <td>Brand was dissolved. Rail operators purchased 1800 spectrum.
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>232</td>
#  <td>01</td>
#  <td>A1.net</td>
#  <td><a class="extiw" href="https://de.wikipedia.org/wiki/Telekom_Austria" title="de:Telekom Austria">A1 Telekom Austria</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 800 / LTE 2600</td>
#  <td>former A1 / Mobilkom / PTA <sup class="reference" id="cite_ref-gsma_austria_45-0"><a href="#cite_note-gsma_austria-45">[45]</a></sup><sup class="reference" id="cite_ref-46"><a href="#cite_note-46">[46]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>02</td>
#  <td></td>
#  <td>A1 Telekom Austria</td>
#  <td>Reserved</td>
#  <td></td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>03</td>
#  <td>T-Mobile AT</td>
#  <td><a class="extiw" href="https://de.wikipedia.org/wiki/T-Mobile_Austria" title="de:T-Mobile Austria">T-Mobile Austria</a></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 900 / UMTS 2100 / LTE 800 / LTE 1800 / LTE 2600</td>
#  <td>former Max.Mobil / national roaming agreement with 232-10 <sup class="reference" id="cite_ref-gsma_austria_45-1"><a href="#cite_note-gsma_austria-45">[45]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>04</td>
#  <td>T-Mobile AT</td>
#  <td>T-Mobile Austria Gmbh</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-12"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>05</td>
#  <td>3</td>
#  <td>Hutchison Drei Austria</td>
#  <td>Operational</td>
#  <td>GSM 900 / UMTS 2100</td>
#  <td>owned by Hutchison Drei Austria / former <a class="extiw" href="https://de.wikipedia.org/wiki/Orange_Austria" title="de:Orange Austria">Orange Austria</a> / One / Connect <sup class="reference" id="cite_ref-gsma_austria_45-2"><a href="#cite_note-gsma_austria-45">[45]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>06</td>
#  <td>Orange AT</td>
#  <td>Orange Austria GmbH</td>
#  <td>Not operational</td>
#  <td>Unknown</td>
#  <td>MNC withdrawn<sup class="reference" id="cite_ref-itu_ob_1019_8-13"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup><sup class="reference" id="cite_ref-itu_ob_1078_47-0"><a href="#cite_note-itu_ob_1078-47">[47]</a></sup><sup class="reference" id="cite_ref-authority_at_48-0"><a href="#cite_note-authority_at-48">[48]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>07</td>
#  <td><a class="extiw" href="https://de.wikipedia.org/wiki/Telering" title="de:Telering">tele.ring</a></td>
#  <td>T-Mobile Austria</td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>brand of T-Mobile Austria
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>08</td>
#  <td>Lycamobile</td>
#  <td><a class="mw-redirect" href="/wiki/LycaMobile" title="LycaMobile">Lycamobile Austria</a></td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>09</td>
#  <td>Tele2Mobil</td>
#  <td>A1 Telekom Austria</td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>division bought from <a class="extiw" href="https://de.wikipedia.org/wiki/Tele2#Österreich" title="de:Tele2">Tele2</a> by A1 Telekom Austria; customers "moved" to bob (232-11)
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>10</td>
#  <td>3</td>
#  <td><a class="extiw" href="https://de.wikipedia.org/wiki/Hutchison_3G_Austria" title="de:Hutchison 3G Austria">Hutchison Drei Austria</a></td>
#  <td>Operational</td>
#  <td>UMTS 2100 / LTE 900 / LTE 1800 / LTE 2100 / LTE 2600</td>
#  <td>national roaming agreement with 232-03, one-way national roaming agreement with 232-01<sup class="reference" id="cite_ref-gsa_lte_4-16"><a href="#cite_note-gsa_lte-4">[4]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>11</td>
#  <td><a class="extiw" href="https://de.wikipedia.org/wiki/Bob_(Mobilfunk)" title="de:Bob (Mobilfunk)">bob</a></td>
#  <td>A1 Telekom Austria</td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>brand of A1 Telekom Austria
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>12</td>
#  <td><a class="extiw" href="https://de.wikipedia.org/wiki/Yesss" title="de:Yesss">yesss!</a></td>
#  <td>A1 Telekom Austria</td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>owned by A1 Telekom Austria / one-way national roaming agreement with 232-05
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>13</td>
#  <td>upc</td>
#  <td><a class="extiw" href="https://de.wikipedia.org/wiki/UPC_Austria" title="de:UPC Austria">UPC Austria</a></td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>14</td>
#  <td></td>
#  <td>Hutchison Drei Austria</td>
#  <td>Reserved</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>15</td>
#  <td>Vectone Mobile</td>
#  <td>Mundio Mobile Austria</td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td>former Barablu Mobile Austria, uses A1<sup class="reference" id="cite_ref-49"><a href="#cite_note-49">[49]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>16</td>
#  <td></td>
#  <td>Hutchison Drei Austria</td>
#  <td>Reserved</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>17</td>
#  <td></td>
#  <td><a class="external text" href="http://www.massresponse.com/" rel="nofollow">MASS Response Service GmbH</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-authority_at_48-1"><a href="#cite_note-authority_at-48">[48]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>18</td>
#  <td></td>
#  <td>smartspace GmbH</td>
#  <td>Unknown</td>
#  <td>MVNO</td>
#  <td><sup class="reference" id="cite_ref-authority_at_48-2"><a href="#cite_note-authority_at-48">[48]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>19</td>
#  <td></td>
#  <td><a href="/wiki/Tele2#Austria" title="Tele2">Tele2 Telecommunication GmbH</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-authority_at_48-3"><a href="#cite_note-authority_at-48">[48]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>20</td>
#  <td>m:tel</td>
#  <td><a href="/wiki/Mtel_CG" title="Mtel CG">MTEL Austrija GmbH</a></td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1078_47-1"><a href="#cite_note-itu_ob_1078-47">[47]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>21</td>
#  <td></td>
#  <td><a class="external text" href="https://www.salzburg-ag.at/" rel="nofollow">Salzburg AG für Energie, Verkehr und Telekommunikation</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-authority_at_48-4"><a href="#cite_note-authority_at-48">[48]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>22</td>
#  <td></td>
#  <td><a class="external text" href="http://www.plintron.com/" rel="nofollow">Plintron Austria Limited</a></td>
#  <td>Unknown</td>
#  <td>MVNO</td>
#  <td><sup class="reference" id="cite_ref-authority_at_48-5"><a href="#cite_note-authority_at-48">[48]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>23</td>
#  <td></td>
#  <td>T-Mobile Austria GmbH</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-authority_at_48-6"><a href="#cite_note-authority_at-48">[48]</a></sup>
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>91</td>
#  <td>GSM-R A</td>
#  <td><a href="/wiki/Austrian_Federal_Railways" title="Austrian Federal Railways">ÖBB</a></td>
#  <td>Operational</td>
#  <td>GSM-R</td>
#  <td>railways communication
#  </td></tr>
#  <tr>
#  <td>232</td>
#  <td>92</td>
#  <td>ArgoNET</td>
#  <td><a class="external text" href="http://www.argonet.at" rel="nofollow">ArgoNET GmbH</a></td>
#  <td>Operational</td>
#  <td>CDMA450 / LTE450</td>
#  <td>machine to machine communication for critical infrastructure <sup class="reference" id="cite_ref-authority_at_48-7"><a href="#cite_note-authority_at-48">[48]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>400</td>
#  <td>01</td>
#  <td><a href="/wiki/Azercell" title="Azercell">Azercell</a></td>
#  <td></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800/ UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte1800_101213_13-3"><a href="#cite_note-gsa_lte1800_101213-13">[13]</a></sup>
#  </td></tr>
#  <tr>
#  <td>400</td>
#  <td>02</td>
#  <td><a href="/wiki/Bakcell" title="Bakcell">Bakcell</a></td>
#  <td></td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-50"><a href="#cite_note-50">[50]</a></sup>
#  </td></tr>
#  <tr>
#  <td>400</td>
#  <td>03</td>
#  <td>FONEX</td>
#  <td><a class="mw-redirect" href="/wiki/CATEL" title="CATEL">CATEL</a></td>
#  <td>Operational</td>
#  <td>CDMA 450</td>
#  <td><sup class="reference" id="cite_ref-51"><a href="#cite_note-51">[51]</a></sup>
#  </td></tr>
#  <tr>
#  <td>400</td>
#  <td>04</td>
#  <td><a href="/wiki/Nar_Mobile" title="Nar Mobile">Nar Mobile</a></td>
#  <td>Azerfon</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-52"><a href="#cite_note-52">[52]</a></sup>
#  </td></tr>
#  <tr>
#  <td>400</td>
#  <td>05</td>
#  <td></td>
#  <td>Special State Protection Service of the Republic of Azerbaijan</td>
#  <td>Unknown</td>
#  <td>TETRA?</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1069_53-0"><a href="#cite_note-itu_ob_1069-53">[53]</a></sup>
#  </td></tr>
#  <tr>
#  <td>400</td>
#  <td>06</td>
#  <td><a class="external text" href="http://www.naxtel.nakhinternet.az/" rel="nofollow">Naxtel</a></td>
#  <td><a href="/wiki/Nakhtel" title="Nakhtel">Nakhtel</a> LLC</td>
#  <td>Operational</td>
#  <td>CDMA 800</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1080_54-0"><a href="#cite_note-itu_ob_1080-54">[54]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>364</td>
#  <td>39</td>
#  <td>BTC</td>
#  <td>The Bahamas Telecommunications Company Ltd (BaTelCo)</td>
#  <td>Operational</td>
#  <td>GSM 850 / GSM 1900 / UMTS 850 / LTE 700</td>
#  <td>LTE band 17 <sup class="reference" id="cite_ref-itu_ob_1112_38-2"><a href="#cite_note-itu_ob_1112-38">[38]</a></sup><sup class="reference" id="cite_ref-55"><a href="#cite_note-55">[55]</a></sup>
#  </td></tr>
#  <tr>
#  <td>364</td>
#  <td>49</td>
#  <td><a class="external text" href="https://www.bealiv.com/" rel="nofollow">Aliv</a></td>
#  <td><a class="external text" href="https://www.cablebahamas.com/" rel="nofollow">Cable Bahamas Ltd</a></td>
#  <td>Operational</td>
#  <td>LTE 700 / LTE 1700</td>
#  <td>Former NewCo 2015;<sup class="reference" id="cite_ref-itu_ob_1108_36-1"><a href="#cite_note-itu_ob_1108-36">[36]</a></sup> LTE bands 13 / 4, license also covers 850MHz and 1900MHz<sup class="reference" id="cite_ref-56"><a href="#cite_note-56">[56]</a></sup>
#  </td></tr></tbody></table>, <table class="wikitable" width="100%">
#  <tbody><tr>
#  <th width="4%">MCC</th>
#  <th width="4%">MNC</th>
#  <th width="12%">Brand</th>
#  <th width="22%">Operator</th>
#  <th width="10%">Status</th>
#  <th width="28%">Bands (MHz)</th>
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>426</td>
#  <td>01</td>
#  <td><a href="/wiki/Batelco" title="Batelco">Batelco</a></td>
#  <td>Bahrain Telecommunications Company</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte1800_101213_13-4"><a href="#cite_note-gsa_lte1800_101213-13">[13]</a></sup><sup class="reference" id="cite_ref-gsma_bahrain_57-0"><a href="#cite_note-gsma_bahrain-57">[57]</a></sup>
#  </td></tr>
#  <tr>
#  <td>426</td>
#  <td>02</td>
#  <td><a href="/wiki/Zain_Group" title="Zain Group">zain BH</a></td>
#  <td>Zain Bahrain</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte1800_101213_13-5"><a href="#cite_note-gsa_lte1800_101213-13">[13]</a></sup><sup class="reference" id="cite_ref-gsma_bahrain_57-1"><a href="#cite_note-gsma_bahrain-57">[57]</a></sup>
#  </td></tr>
#  <tr>
#  <td>426</td>
#  <td>03</td>
#  <td></td>
#  <td>Civil Aviation Authority</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-14"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup>
#  </td></tr>
#  <tr>
#  <td>426</td>
#  <td>04</td>
#  <td><a href="/wiki/VIVA_Bahrain" title="VIVA Bahrain">VIVA Bahrain</a></td>
#  <td>Viva Bahrain</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800</td>
#  <td><sup class="reference" id="cite_ref-gsa_lte1800_101213_13-6"><a href="#cite_note-gsa_lte1800_101213-13">[13]</a></sup><sup class="reference" id="cite_ref-gsma_bahrain_57-2"><a href="#cite_note-gsma_bahrain-57">[57]</a></sup>
#  </td></tr>
#  <tr>
#  <td>426</td>
#  <td>05</td>
#  <td><a href="/wiki/Batelco" title="Batelco">Batelco</a></td>
#  <td>Bahrain Telecommunications Company</td>
#  <td>Operational</td>
# ...
#  <th width="20%">References and notes
#  </th></tr>
#  <tr>
#  <td>901</td>
#  <td>01</td>
#  <td>ICO</td>
#  <td><a class="mw-redirect" href="/wiki/ICO_Satellite_Management" title="ICO Satellite Management">ICO Satellite Management</a></td>
#  <td>Not operational</td>
#  <td>Satellite</td>
#  <td>MNC withdrawn<sup class="reference" id="cite_ref-itu_ob_1091_165-1"><a href="#cite_note-itu_ob_1091-165">[165]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>02</td>
#  <td></td>
#  <td><i>Unassigned</i></td>
#  <td>Returned spare</td>
#  <td>Unknown</td>
#  <td>Formerly: Sense Communications International
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>03</td>
#  <td><a class="mw-redirect" href="/wiki/Iridium_Satellite_LLC" title="Iridium Satellite LLC">Iridium</a></td>
#  <td></td>
#  <td>Operational</td>
#  <td>Satellite</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>04</td>
#  <td></td>
#  <td><i>Unassigned</i></td>
#  <td>Returned spare</td>
#  <td>Satellite</td>
#  <td>Formerly: <a href="/wiki/Globalstar" title="Globalstar">Globalstar</a>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>05</td>
#  <td></td>
#  <td><a href="/wiki/Thuraya" title="Thuraya">Thuraya</a> RMSS Network</td>
#  <td>Operational</td>
#  <td>Satellite</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>06</td>
#  <td></td>
#  <td><a href="/wiki/Thuraya" title="Thuraya">Thuraya</a> Satellite Telecommunications Company</td>
#  <td>Operational</td>
#  <td>Satellite</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>07</td>
#  <td></td>
#  <td><i>Unassigned</i></td>
#  <td>Returned spare</td>
#  <td>Unknown</td>
#  <td>Formerly: Ellipso
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>08</td>
#  <td></td>
#  <td><i>Unassigned</i></td>
#  <td>Returned spare</td>
#  <td>Unknown</td>
#  <td>Formerly: GSM, reserved for station identification where the mobile does not have a subscription IMSI
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>09</td>
#  <td></td>
#  <td><i>Unassigned</i></td>
#  <td>Returned spare</td>
#  <td>Unknown</td>
#  <td>Formerly: Tele1 Europe
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>10</td>
#  <td><a href="/wiki/ACeS" title="ACeS">ACeS</a></td>
#  <td></td>
#  <td>Not operational</td>
#  <td>Satellite</td>
#  <td>MNC withdrawn<sup class="reference" id="cite_ref-itu_ob_1091_165-2"><a href="#cite_note-itu_ob_1091-165">[165]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>11</td>
#  <td><a href="/wiki/Inmarsat" title="Inmarsat">Inmarsat</a></td>
#  <td></td>
#  <td>Operational</td>
#  <td>Satellite</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>12</td>
#  <td><a href="/wiki/Telenor" title="Telenor">Telenor</a></td>
#  <td><a class="external text" href="http://telenormaritime.com" rel="nofollow">Telenor Maritime AS</a></td>
#  <td>Operational</td>
#  <td>GSM 1800 / LTE 800</td>
#  <td>Maritime; formerly Maritime Communications Partner (MCP)
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>13</td>
#  <td><a class="external text" href="https://web.archive.org/web/20040806020023/http://gsm.aq/" rel="nofollow">GSM.AQ</a></td>
#  <td>BebbiCell AG</td>
#  <td>Operational</td>
#  <td>GSM 1800</td>
#  <td><a href="/wiki/Antarctica" title="Antarctica">Antarctica</a> +88234 Network; formerly Global Networks Switzerland Inc.
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>14</td>
#  <td>AeroMobile</td>
#  <td><a class="external text" href="http://www.aeromobile.net/" rel="nofollow">AeroMobile AS</a></td>
#  <td>Operational</td>
#  <td>GSM 1800</td>
#  <td>Air <sup class="reference" id="cite_ref-itu_ob_1103_151-21"><a href="#cite_note-itu_ob_1103-151">[151]</a></sup><sup class="reference" id="cite_ref-mwlive_9-100"><a href="#cite_note-mwlive-9">[9]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>15</td>
#  <td><a class="mw-redirect" href="/wiki/OnAir" title="OnAir">OnAir</a></td>
#  <td><a class="external text" href="http://www.onair.aero/" rel="nofollow">OnAir Switzerland Sarl</a></td>
#  <td>Operational</td>
#  <td>GSM 1800</td>
#  <td>Air
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>16</td>
#  <td><a href="/wiki/Cisco_Jasper" title="Cisco Jasper">Cisco Jasper</a></td>
#  <td>Cisco Systems, Inc.</td>
#  <td>Operational</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1120_308-1"><a href="#cite_note-itu_ob_1120-308">[308]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>17</td>
#  <td>Navitas</td>
#  <td><a href="/wiki/JT_Group_Limited" title="JT Group Limited">JT Group Limited</a></td>
#  <td>Not operational</td>
#  <td>GSM 1800</td>
#  <td>Maritime; <a href="/wiki/JT_Group_Limited#1980s_to_today" title="JT Group Limited">shut down in 2009</a>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>18</td>
#  <td>Cellular @Sea</td>
#  <td>AT&amp;T Mobility</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1900 / CDMA2000 1900 / UMTS 1900</td>
#  <td>Maritime <a class="external autonumber" href="http://www.wmsatsea.com/" rel="nofollow">[4]</a>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>19</td>
#  <td></td>
#  <td><a href="/wiki/Vodafone_Malta" title="Vodafone Malta">Vodafone Malta</a> Maritime</td>
#  <td>Operational</td>
#  <td>GSM 900 / GSM 1800 / UMTS 2100</td>
#  <td>Maritime <sup class="reference" id="cite_ref-bell_cruise_ships_173-1"><a href="#cite_note-bell_cruise_ships-173">[173]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>20</td>
#  <td></td>
#  <td>Intermatica</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>21</td>
#  <td></td>
#  <td>Wins Limited</td>
#  <td>Operational</td>
#  <td>GSM 1800</td>
#  <td>Maritime; formerly Seanet Maritime Communications <sup class="reference" id="cite_ref-itu_ob_1056_20-89"><a href="#cite_note-itu_ob_1056-20">[20]</a></sup><sup class="reference" id="cite_ref-mwlive_9-101"><a href="#cite_note-mwlive-9">[9]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>22</td>
#  <td></td>
#  <td>MediaLincc Ltd</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>23</td>
#  <td></td>
#  <td><i>Unassigned</i></td>
#  <td>Returned spare</td>
#  <td>Unknown</td>
#  <td>Formerly: <a href="/wiki/Beeline_(brand)" title="Beeline (brand)">Beeline</a>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>24</td>
#  <td>iNum</td>
#  <td><a href="/wiki/Voxbone" title="Voxbone">Voxbone</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><a href="/wiki/International_Networks_(country_code)" title="International Networks (country code)">+883 iNum</a> <sup class="reference" id="cite_ref-itu_e212_901_371-0"><a href="#cite_note-itu_e212_901-371">[371]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>25</td>
#  <td></td>
#  <td><i>Unassigned</i></td>
#  <td>Returned spare</td>
#  <td>Unknown</td>
#  <td>Formerly: In &amp; phone
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>26</td>
#  <td>TIM@sea</td>
#  <td><a class="mw-redirect" href="/wiki/Telecom_Italia_Mobile" title="Telecom Italia Mobile">Telecom Italia Mobile</a></td>
#  <td>Operational</td>
#  <td>GSM 1800 / GSM 1900</td>
#  <td>Maritime <sup class="reference" id="cite_ref-372"><a href="#cite_note-372">[372]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>27</td>
#  <td>OnMarine</td>
#  <td><a href="/wiki/Monaco_Telecom" title="Monaco Telecom">Monaco Telecom</a></td>
#  <td>Operational</td>
#  <td>GSM 1800</td>
#  <td>Maritime<sup class="reference" id="cite_ref-itu_ob_1113_194-2"><a href="#cite_note-itu_ob_1113-194">[194]</a></sup><sup class="reference" id="cite_ref-mwlive_9-102"><a href="#cite_note-mwlive-9">[9]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>28</td>
#  <td><a href="/wiki/Vodafone" title="Vodafone">Vodafone</a></td>
#  <td>GDSP (Vodafone's Global Data Service Platform)</td>
#  <td>Operational</td>
#  <td>Roaming SIM</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>29</td>
#  <td><a href="/wiki/Telenor" title="Telenor">Telenor</a></td>
#  <td></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>30</td>
#  <td></td>
#  <td><i>Unassigned</i></td>
#  <td>Returned spare</td>
#  <td>Unknown</td>
#  <td>Formerly: Terrestar Networks
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>31</td>
#  <td><a href="/wiki/Orange_S.A." title="Orange S.A.">Orange</a></td>
#  <td>Orange S.A.</td>
#  <td>Operational</td>
#  <td>GSM 900</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>32</td>
#  <td>Sky High</td>
#  <td><a href="/wiki/MegaFon" title="MegaFon">MegaFon</a></td>
#  <td>Operational</td>
#  <td>GSM 900</td>
#  <td>Air (<a href="/wiki/Aeroflot" title="Aeroflot">Aeroflot</a>)
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>33</td>
#  <td></td>
#  <td>Smart Communications</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>34</td>
#  <td></td>
#  <td><a href="/wiki/Tyntec" title="Tyntec">tyntec</a> GmbH</td>
#  <td>Unknown</td>
#  <td>MVNO</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>35</td>
#  <td></td>
#  <td>Globecomm Network Services</td>
#  <td>Operational</td>
#  <td>GSM 850</td>
#  <td>Maritime <sup class="reference" id="cite_ref-mwlive_9-103"><a href="#cite_note-mwlive-9">[9]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>36</td>
#  <td></td>
#  <td>Azerfon</td>
#  <td>Operational</td>
#  <td>GSM 1800</td>
#  <td>Air
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>37</td>
#  <td></td>
#  <td><a href="/wiki/Transatel" title="Transatel">Transatel</a></td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1019_8-117"><a href="#cite_note-itu_ob_1019-8">[8]</a></sup> Global SIM for Data Mobile Broadband and M2M
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>38</td>
#  <td></td>
#  <td><a href="/wiki/Multiregional_TransitTelecom" title="Multiregional TransitTelecom">Multiregional TransitTelecom</a> (MTT)</td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1056_20-90"><a href="#cite_note-itu_ob_1056-20">[20]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>39</td>
#  <td></td>
#  <td><a class="external text" href="http://www.mtxc.eu/" rel="nofollow">MTX Connect Ltd</a></td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1038_150-1"><a href="#cite_note-itu_ob_1038-150">[150]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>40</td>
#  <td></td>
#  <td><a href="/wiki/Deutsche_Telekom" title="Deutsche Telekom">Deutsche Telekom</a> AG</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1055_29-1"><a href="#cite_note-itu_ob_1055-29">[29]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>41</td>
#  <td></td>
#  <td><a class="external text" href="http://www.bodytrace.com/" rel="nofollow">BodyTrace Netherlands B.V.</a></td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1057_141-2"><a href="#cite_note-itu_ob_1057-141">[141]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>42</td>
#  <td></td>
#  <td>DCN Hub ehf</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1061_145-1"><a href="#cite_note-itu_ob_1061-145">[145]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>43</td>
#  <td></td>
#  <td><a class="external text" href="https://www.emnify.com/" rel="nofollow">EMnify GmbH</a></td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1062_199-3"><a href="#cite_note-itu_ob_1062-199">[199]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>44</td>
#  <td></td>
#  <td>AT&amp;T Inc.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1069_53-3"><a href="#cite_note-itu_ob_1069-53">[53]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>45</td>
#  <td></td>
#  <td><a class="external text" href="http://www.awn.co.th/en/" rel="nofollow">Advanced Wireless Network Company Limited</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td>subsidiary of <a href="/wiki/Advanced_Info_Service" title="Advanced Info Service">Advanced Info Service</a> <sup class="reference" id="cite_ref-itu_ob_1073_260-2"><a href="#cite_note-itu_ob_1073-260">[260]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>46</td>
#  <td></td>
#  <td><a class="external text" href="http://www.telecom26.ch/" rel="nofollow">Telecom26 AG</a></td>
#  <td>Operational</td>
#  <td>MVNO</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1077_162-5"><a href="#cite_note-itu_ob_1077-162">[162]</a></sup><sup class="reference" id="cite_ref-itu_e212_901_371-1"><a href="#cite_note-itu_e212_901-371">[371]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>47</td>
#  <td></td>
#  <td><a href="/wiki/Ooredoo" title="Ooredoo">Ooredoo</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1079_63-3"><a href="#cite_note-itu_ob_1079-63">[63]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>48</td>
#  <td>Com4</td>
#  <td>Communication for Devices in Sweden AB</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1087_136-11"><a href="#cite_note-itu_ob_1087-136">[136]</a></sup><sup class="reference" id="cite_ref-itu_ob_1115_281-2"><a href="#cite_note-itu_ob_1115-281">[281]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>49</td>
#  <td></td>
#  <td><a href="/wiki/Zain_Group" title="Zain Group">Zain Kuwait</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1091_165-3"><a href="#cite_note-itu_ob_1091-165">[165]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>50</td>
#  <td></td>
#  <td><a href="/wiki/EchoStar_Mobile" title="EchoStar Mobile">EchoStar Mobile</a></td>
#  <td>Unknown</td>
#  <td>Satellite</td>
#  <td>Also listed as Sawatch Limited<sup class="reference" id="cite_ref-itu_ob_1092_110-13"><a href="#cite_note-itu_ob_1092-110">[110]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>51</td>
#  <td></td>
#  <td><a class="external text" href="https://web.archive.org/web/20071011025024/http://www.visionng.com/" rel="nofollow">VisionNG</a></td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1095_373-0"><a href="#cite_note-itu_ob_1095-373">[373]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>52</td>
#  <td></td>
#  <td><a href="/wiki/Manx_Telecom" title="Manx Telecom">Manx Telecom</a> Trading Ltd.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1110_142-3"><a href="#cite_note-itu_ob_1110-142">[142]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>53</td>
#  <td></td>
#  <td><a href="/wiki/Deutsche_Telekom" title="Deutsche Telekom">Deutsche Telekom</a> AG</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1111_37-16"><a href="#cite_note-itu_ob_1111-37">[37]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>54</td>
#  <td></td>
#  <td>Teleena Holding B.V.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1118_10-15"><a href="#cite_note-itu_ob_1118-10">[10]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>55</td>
#  <td></td>
#  <td>Beezz Communication Solutions Ltd.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1120_308-2"><a href="#cite_note-itu_ob_1120-308">[308]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>56</td>
#  <td><a href="/wiki/ETSI" title="ETSI">ETSI</a></td>
#  <td>European Telecommunications Standards Institute</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1125_374-0"><a href="#cite_note-itu_ob_1125-374">[374]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>57</td>
#  <td></td>
#  <td>SAP</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1126_375-0"><a href="#cite_note-itu_ob_1126-375">[375]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>58</td>
#  <td>BICS</td>
#  <td><a href="/wiki/Belgacom_ICS" title="Belgacom ICS">Belgacom ICS</a> SA</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1130_376-0"><a href="#cite_note-itu_ob_1130-376">[376]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>59</td>
#  <td></td>
#  <td>MessageBird B.V.</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1147_203-3"><a href="#cite_note-itu_ob_1147-203">[203]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>60</td>
#  <td></td>
#  <td>OneWeb</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td><sup class="reference" id="cite_ref-itu_ob_1147_203-4"><a href="#cite_note-itu_ob_1147-203">[203]</a></sup>
#  </td></tr>
#  <tr>
#  <td>901</td>
#  <td>88</td>
#  <td></td>
#  <td>UN Office for the Coordination of Humanitarian Affairs (OCHA)</td>
#  <td>Unknown</td>
#  <td>Unknown</td>
#  <td>
#  </td></tr></tbody></table>]

# %%
for table in tables:
    for row in table.find_all('tr'):
        for col in row.find_all('td'):
            if col is not None:
                if col.string == 'au':
                    print([''.join([p.string for p in td.contents]) for td in row.find_all('td')])
# Out:
# ['440', '50', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '51', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '52', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '53', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '54', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '70', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '71', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '72', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '73', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '74', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '75', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '76', 'au', 'KDDI Corporation', 'Operational', 'CDMA2000 850 / CDMA2000 2100 / LTE 700 / LTE 850 / LTE 1500 / LTE 2100 / TD-LTE 3500', 'bands 1, 11, 26 (18), 28, 42[148]\n']
# ['440', '78', 'au', 'Okinawa Cellular Telephone', 'Operational', 'CDMA2000 850 / CDMA2000 2100', '[148]\n']

# %%
MCCs = []
for nation in nations:
    for operator in parse_nation(nation):
        MCCs.append(operator)

# %%
tag = '<td><a href="/wiki/Colo-Colo" title="Colo-Colo">Colo-Colo</a> Móvil<br/><a class="extiw" href="https://es.wikipedia.org/wiki/Santiago_Wanderers" title="es:Santiago Wanderers">Wanderers</a> Móvil</td>'

# %%
t = BeautifulSoup(tag, 'lxml').td

# %%
t
# Out:
# <td><a href="/wiki/Colo-Colo" title="Colo-Colo">Colo-Colo</a> Móvil<br/><a class="extiw" href="https://es.wikipedia.org/wiki/Santiago_Wanderers" title="es:Santiago Wanderers">Wanderers</a> Móvil</td>

# %%
''.join(t.strings)
# Out:
# 'Colo-Colo MóvilWanderers Móvil'

# %%
print(MCCs)
# Out:
# [{'Nation': 'Abkhazia', 'MCC': '289', 'MNC': '67', 'Brand': 'Aquafon', 'Operator': 'Aquafon JSC', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 800'}, {'Nation': 'Abkhazia', 'MCC': '289', 'MNC': '88', 'Brand': 'A-Mobile', 'Operator': 'A-Mobile LLSC', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 800 / LTE 1800'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '01', 'Brand': 'AWCC', 'Operator': 'Afghan Wireless Communication Company', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '20', 'Brand': 'Roshan', 'Operator': 'Telecom Development Company Afghanistan Ltd.', 'Status': 'Operational', 'Bands': 'GSM 900 / UMTS'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '40', 'Brand': 'MTN', 'Operator': 'MTN Group Afghanistan', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '50', 'Brand': 'Etisalat', 'Operator': 'Etisalat Afghanistan', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '55', 'Brand': 'WASEL', 'Operator': 'WASEL Afghanistan', 'Status': 'Operational', 'Bands': 'CDMA 800'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '80', 'Brand': 'Salaam', 'Operator': 'Afghan Telecom', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '88', 'Brand': 'Salaam', 'Operator': 'Afghan Telecom', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Albania', 'MCC': '276', 'MNC': '01', 'Brand': 'Telekom.al', 'Operator': 'Telekom Albania', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800 / LTE 2600'}, {'Nation': 'Albania', 'MCC': '276', 'MNC': '02', 'Brand': 'Vodafone', 'Operator': 'Vodafone Albania', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800 / LTE 2600'}, {'Nation': 'Albania', 'MCC': '276', 'MNC': '03', 'Brand': 'Eagle Mobile', 'Operator': 'Albtelecom', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Albania', 'MCC': '276', 'MNC': '04', 'Brand': 'Plus Communication', 'Operator': 'Plus Communication', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '01', 'Brand': 'Mobilis', 'Operator': 'Algérie Télécom', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '02', 'Brand': 'Djezzy', 'Operator': 'Optimum Telecom Algérie Spa', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '03', 'Brand': 'Ooredoo', 'Operator': 'Wataniya Telecom Algérie', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '07', 'Brand': 'AT', 'Operator': 'Algérie Télécom', 'Status': 'Operational', 'Bands': 'CDMA 1900'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '09', 'Brand': 'AT', 'Operator': 'Algérie Télécom', 'Status': 'Operational', 'Bands': 'LTE'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '21', 'Brand': 'ANESRIF', 'Operator': 'Anesrif', 'Status': 'Ongoing', 'Bands': 'GSM-R'}, {'Nation': 'American Samoa', 'MCC': '544', 'MNC': '11', 'Brand': 'Bluesky', 'Operator': 'Bluesky', 'Status': 'Operational', 'Bands': 'GSM 850 / GSM 1900 / UMTS 850 / LTE 700 / LTE 1700'}, {'Nation': 'Andorra', 'MCC': '213', 'MNC': '03', 'Brand': 'Mobiland', 'Operator': 'Servei De Tele. DAndorra', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 800'}, {'Nation': 'Angola', 'MCC': '631', 'MNC': '02', 'Brand': 'UNITEL', 'Operator': 'UNITEL S.a.r.l.', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Angola', 'MCC': '631', 'MNC': '04', 'Brand': 'MOVICEL', 'Operator': 'MOVICEL Telecommunications S.A.', 'Statu ...

# %%
intl_operators = nation.find_all_next('h2')[0]
for operator in parse_intl(intl_operators):
    MCCs.append(operator)
print(MCCs)
# Out:
# [{'Nation': 'Abkhazia', 'MCC': '289', 'MNC': '67', 'Brand': 'Aquafon', 'Operator': 'Aquafon JSC', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 800'}, {'Nation': 'Abkhazia', 'MCC': '289', 'MNC': '88', 'Brand': 'A-Mobile', 'Operator': 'A-Mobile LLSC', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 800 / LTE 1800'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '01', 'Brand': 'AWCC', 'Operator': 'Afghan Wireless Communication Company', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '20', 'Brand': 'Roshan', 'Operator': 'Telecom Development Company Afghanistan Ltd.', 'Status': 'Operational', 'Bands': 'GSM 900 / UMTS'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '40', 'Brand': 'MTN', 'Operator': None, 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '50', 'Brand': 'Etisalat', 'Operator': 'Etisalat Afghanistan', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '55', 'Brand': 'WASEL', 'Operator': 'WASEL Afghanistan', 'Status': 'Operational', 'Bands': 'CDMA 800'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '80', 'Brand': 'Salaam', 'Operator': 'Afghan Telecom', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Afghanistan', 'MCC': '412', 'MNC': '88', 'Brand': 'Salaam', 'Operator': 'Afghan Telecom', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Albania', 'MCC': '276', 'MNC': '01', 'Brand': 'Telekom.al', 'Operator': 'Telekom Albania', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800 / LTE 2600'}, {'Nation': 'Albania', 'MCC': '276', 'MNC': '02', 'Brand': 'Vodafone', 'Operator': 'Vodafone Albania', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800 / LTE 2600'}, {'Nation': 'Albania', 'MCC': '276', 'MNC': '03', 'Brand': 'Eagle Mobile', 'Operator': 'Albtelecom', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Albania', 'MCC': '276', 'MNC': '04', 'Brand': 'Plus Communication', 'Operator': 'Plus Communication', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '01', 'Brand': 'Mobilis', 'Operator': 'Algérie Télécom', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '02', 'Brand': 'Djezzy', 'Operator': None, 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '03', 'Brand': 'Ooredoo', 'Operator': 'Wataniya Telecom Algérie', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '07', 'Brand': 'AT', 'Operator': 'Algérie Télécom', 'Status': 'Operational', 'Bands': 'CDMA 1900'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '09', 'Brand': 'AT', 'Operator': 'Algérie Télécom', 'Status': 'Operational', 'Bands': 'LTE'}, {'Nation': 'Algeria', 'MCC': '603', 'MNC': '21', 'Brand': 'ANESRIF', 'Operator': 'Anesrif', 'Status': 'Ongoing', 'Bands': 'GSM-R'}, {'Nation': 'American Samoa', 'MCC': '544', 'MNC': '11', 'Brand': 'Bluesky', 'Operator': 'Bluesky', 'Status': 'Operational', 'Bands': 'GSM 850 / GSM 1900 / UMTS 850 / LTE 700 / LTE 1700'}, {'Nation': 'Andorra', 'MCC': '213', 'MNC': '03', 'Brand': 'Mobiland', 'Operator': 'Servei De Tele. DAndorra', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 800'}, {'Nation': 'Angola', 'MCC': '631', 'MNC': '02', 'Brand': 'UNITEL', 'Operator': 'UNITEL S.a.r.l.', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800'}, {'Nation': 'Angola', 'MCC': '631', 'MNC': '04', 'Brand': 'MOVICEL', 'Operator': 'MOVICEL Telecommunications S.A.', 'Status': 'Operational', 'Bands': 'GSM 900 / GSM 1 ...

# %%
[(m['MCC'], m['MNC'], m['Bands']) for m in MCCs
 if m['Nation'] == 'United States of America'
 and m['Brand'] == 'AT&T'
 and (
     m['Status'] == 'Unknown'
     or m['Status'] == 'Operational')]
# Out:
# [('310', '030', 'GSM 850'),
#  ('310', '070', 'GSM 850'),
#  ('310', '080', 'GSM 1900'),
#  ('310', '090', 'GSM 1900'),
#  ('310', '150', 'GSM 850 / UMTS 850 / UMTS 1900'),
#  ('310', '170', 'GSM 1900'),
#  ('310', '410', 'GSM 850 / GSM 1900 / UMTS 850 / UMTS 1900'),
#  ('310', '670', 'Unknown'),
#  ('310', '680', 'GSM 850 / GSM 1900'),
#  ('310', '950', 'GSM 850'),
#  ('311', '070', 'GSM 850'),
#  ('311', '090', 'GSM 1900'),
#  ('311', '190', 'Unknown'),
#  ('312', '090', 'Unknown'),
#  ('312', '680', 'Unknown'),
#  ('313', '210', 'Unknown')]

# %%
[(m['Operator'], m['MCC'], m['MNC'], m['Bands']) for m in MCCs
 if m['Nation'] == 'United States of America'
 and 'LTE' in m['Bands']]

# %%
set([m['Nation'] for m in MCCs])
# Out:
# {'Abkhazia',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Ascension Island',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bonaire, Saba, Sint Eustatius',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Indian Ocean Territory',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Christmas Island',
#  'Cocos Islands',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook Islands',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czech Republic',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'East Timor',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Falkland Islands',
#  'Faroe Islands',
#  'Federated States of Micronesia',
#  'Fiji',
#  'Finland',
#  'Former Netherlands Antilles',
#  'France',
#  'French Antilles',
#  'French Guiana',
#  'French Indian Ocean Territories',
#  'French Polynesia',
#  'French Southern Territories',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guernsey',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macau',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Martinique',
#  'Mauritania',
#  'Mauritius',
#  'Mayotte',
#  'Mexico',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Niue',
#  'Norfolk Island',
#  'North Korea',
#  'Northern Mariana Islands',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palau',
#  'Palestine',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Pitcairn Islands',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Réunion',
#  'Saint Barthélemy',
#  'Saint Helena, Ascension and Tristan da Cunha',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Martin',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Sint Maarten',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Korea',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Tokelau',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tristan da Cunha',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States of America',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vatican',
#  'Venezuela',
#  'Vietnam',
#  'Wallis and Futuna',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe'}

# %%
[m for m in MCCs if m['Nation'] == 'Slovakia']
# Out:
# [{'Nation': 'Slovakia',
#   'MCC': '231',
#   'MNC': '01',
#   'Brand': 'Orange',
#   'Operator': 'Orange Slovensko',
#   'Status': 'Operational',
#   'Bands': 'GSM 900 / GSM 1800 / UMTS 900 / UMTS 2100 / LTE 800 / LTE 2600'},
#  {'Nation': 'Slovakia',
#   'MCC': '231',
#   'MNC': '02',
#   'Brand': 'Telekom',
#   'Operator': 'Slovak Telekom',
#   'Status': 'Operational',
#   'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 800 / LTE 1800 / LTE 2600 / TD-LTE 3700'},
#  {'Nation': 'Slovakia',
#   'MCC': '231',
#   'MNC': '03',
#   'Brand': '4ka',
#   'Operator': 'SWAN Mobile, a.s.',
#   'Status': 'Operational',
#   'Bands': 'LTE 1800 / TD-LTE 3500 / TD-LTE 3700'},
#  {'Nation': 'Slovakia',
#   'MCC': '231',
#   'MNC': '04',
#   'Brand': 'Telekom',
#   'Operator': 'Slovak Telekom',
#   'Status': 'Operational',
#   'Bands': 'GSM 900 / GSM 1800 / UMTS 2100'},
#  {'Nation': 'Slovakia',
#   'MCC': '231',
#   'MNC': '05',
#   'Brand': 'Orange',
#   'Operator': 'Orange Slovensko',
#   'Status': 'Operational',
#   'Bands': 'GSM 900 / GSM 1800 / UMTS 900 / UMTS 2100'},
#  {'Nation': 'Slovakia',
#   'MCC': '231',
#   'MNC': '06',
#   'Brand': 'O2',
#   'Operator': 'Telefónica O2 Slovakia',
#   'Status': 'Operational',
#   'Bands': 'GSM 900 / GSM 1800 / UMTS 2100 / LTE 800 / LTE 1800 / TD-LTE 3500 / TD-LTE 3700'},
#  {'Nation': 'Slovakia',
#   'MCC': '231',
#   'MNC': '07',
#   'Brand': '',
#   'Operator': 'Towercom, a. s.',
#   'Status': 'Unknown',
#   'Bands': 'Unknown'},
#  {'Nation': 'Slovakia',
#   'MCC': '231',
#   'MNC': '08',
#   'Brand': '',
#   'Operator': 'IPfon, s.r.o.',
#   'Status': 'Unknown',
#   'Bands': 'Unknown'},
#  {'Nation': 'Slovakia',
#   'MCC': '231',
#   'MNC': '99',
#   'Brand': 'ŽSR',
#   'Operator': 'Železnice Slovenskej Republiky',
#   'Status': 'Operational',
#   'Bands': 'GSM-R'}]
